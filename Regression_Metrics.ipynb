# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('finance_data.csv')
df
# Out:
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000
# 5   31    26500
# 6   33    27000

# %%
x = df.iloc[:,:1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0    10000
# 1    15000
# 2    18000
# 3    21000
# 4    24000
# 5    26500
# 6    27000
# Name: Premium, dtype: int64

# %%
plt.scatter(df["Age"],df["Premium"])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state = 2)

# %%
y_train
# Out:
# 3    21000
# 2    18000
# 6    27000
# 5    26500
# 0    10000
# Name: Premium, dtype: int64

# %%
y_test
# Out:
# 4    24000
# 1    15000
# Name: Premium, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#    Age
# 4   28
# 1   22

# %%
y_test
# Out:
# 4    24000
# 1    15000
# Name: Premium, dtype: int64

# %%
y_pred = lr.predict(X_test)

# %% [markdown]
# # Regression Metrices

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
print("MAE", mean_absolute_error(y_test,y_pred))
# Out:
# MAE 1087.1934604904636

# %%
print("MSE", mean_squared_error(y_test,y_pred))
# Out:
# MSE 1315304.14510465

# %%
print("RMSE", np.sqrt(mean_absolute_error(y_test,y_pred)))
# Out:
# RMSE 32.97261682806604

# %%
print("R2 Score", r2_score(y_test,y_pred))
# Out:
# R2 Score 0.935046708883721

# %%
r2 = r2_score(y_test,y_pred)

# %%
print("Adjusted R2 Score", 1 - (((1-r2) * (len(df["Age"]) - 1))) / len(df["Age"]) - 1 - 2 )
# Out:
# Adjusted R2 Score -2.055674249528239
